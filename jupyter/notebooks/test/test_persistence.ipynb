# %%
import time
from datetime import datetime

test_var = "I should survive SSH disconnect!"
print(f"Variable created: {test_var}")
print(f"Started at: {datetime.now().strftime('%H:%M:%S')}")
print("\nNow DISCONNECT your SSH/Cursor!")
print("Wait 30 seconds, then RECONNECT and run the next cell\n")

# Optional: long running process
for i in range(30):
    print(f"[{datetime.now().strftime('%H:%M:%S')}] Iteration {i+1}/30")
    time.sleep(10)  # 5 minutes total

# %%
# Run this cell after reconnecting
print(f"Variable still exists: {test_var}")  # Should work!
print("✅ SUCCESS!" if 'test_var' in dir() else "❌ FAILED")
